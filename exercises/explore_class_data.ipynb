# %% [markdown]
# # Explore the class dataset
# **November 2, 2016**
#
# The goal is to learn pandas functions by exploring the toy dataset class_data.txt.  Each section of the notebook has a task to complete.

# %% [markdown]
# ## Load the data
# Load the file class_data.txt in the data subdirectory as a pandas data frame.  It is a tab-separated text file.  See the `read_csv` pandas command and python `os` module for working with file names.  Use the pandas `head` command to inspect the columns.

# %%
import os
import pandas as pd

test_df = pd.read_csv('../data/class_data.txt', sep = '\t')
test_df[:26]
# Out:
#    Student initials       Year    Major  Homework 1  Homework 2  Homework 3  \
# 0                AA   Freshman       CS         2.0         2.0         1.0
# 1                BB   Freshman       CS         0.0         1.0         3.0
# 2                CC   Freshman       CS         3.0         2.0         3.0
# 3                DD   Freshman  Biology         1.0         1.0         0.0
# 4                EE   Freshman  Biology         1.0         1.0         2.0
# 5                FF  Sophomore  Biology         3.0         4.0         3.0
# 6                GG  Sophomore    Dance         4.0         4.0         4.0
# 7                HH     Junior       CS         4.0         3.0         1.0
# 8                II     Junior  Biology         4.0         2.0         5.0
# 9                JJ     Junior  Biology         3.0         3.0         4.0
# 10               KK     Junior       CS         2.0         3.0         5.0
# ...

# %% [markdown]
# ## Count the number of students in the class

# %%
test_df['Student initials'].count()
# Out:
# 26

# %% [markdown]
# ## Display summary statistics
# See pandas `describe`

# %%
test_df.describe()
# Out:
#        Homework 1  Homework 2  Homework 3  Homework 4     Exam 1     Exam 2  \
# count   26.000000   26.000000   26.000000   26.000000  26.000000  26.000000
# mean     2.923077    2.807692    2.653846    2.692308  15.115385  14.961538
# std      1.467599    1.523660    1.521639    1.715091   6.525807   5.983182
# min      0.000000    0.000000    0.000000    0.000000   5.000000   6.000000
# 25%      2.000000    2.000000    1.250000    1.000000   9.500000  10.250000
# 50%      3.000000    3.000000    3.000000    2.000000  14.000000  14.000000
# 75%      4.000000    4.000000    3.750000    4.750000  21.000000  19.500000
# max      5.000000    5.000000    5.000000    5.000000  25.000000  25.000000
#
#          Project
# count  26.000000
# mean   19.538462
# std     7.674533
# min     5.000000
# 25%    16.000000
# 50%    19.000000
# 75%    26.000000
# max    30.000000

# %% [markdown]
# ## Sort the data frame by the project grade

# %%
test_df.sort_values(by='Project')
# Out:
#    Student initials       Year    Major  Homework 1  Homework 2  Homework 3  \
# 3                DD   Freshman  Biology         1.0         1.0         0.0
# 4                EE   Freshman  Biology         1.0         1.0         2.0
# 22               WW   Freshman       CS         1.0         2.0         1.0
# 1                BB   Freshman       CS         0.0         1.0         3.0
# 2                CC   Freshman       CS         3.0         2.0         3.0
# 12               MM     Senior       CS         4.0         2.0         3.0
# 19               TT     Junior  Biology         2.0         1.0         3.0
# 9                JJ     Junior  Biology         3.0         3.0         4.0
# 21               VV   Freshman       CS         1.0         0.0         2.0
# 0                AA   Freshman       CS         2.0         2.0         1.0
# 15               PP  Sophomore       CS         3.0         4.0         2.0
# ...

# %% [markdown]
# ## Display only the students who are Biology majors

# %%
test_df[test_df['Major'].isin(['Biology'])]
# Out:
#    Student initials       Year    Major  Homework 1  Homework 2  Homework 3  \
# 3                DD   Freshman  Biology         1.0         1.0         0.0
# 4                EE   Freshman  Biology         1.0         1.0         2.0
# 5                FF  Sophomore  Biology         3.0         4.0         3.0
# 8                II     Junior  Biology         4.0         2.0         5.0
# 9                JJ     Junior  Biology         3.0         3.0         4.0
# 11               LL     Senior  Biology         4.0         5.0         3.0
# 19               TT     Junior  Biology         2.0         1.0         3.0
# 20               UU   Freshman  Biology         3.0         0.0         0.0
# 24               YY  Sophomore  Biology         5.0         5.0         3.0
#
#     Homework 4  Exam 1  Exam 2  Project
# 3          3.0    13.0    14.0      5.0
# 4          0.0     8.0     8.0      6.0
# 5          2.0     6.0    13.0     20.0
# 8          1.0     6.0    18.0     24.0
# ...

# %%
# Alternative
test_df[test_df['Major'] == 'Biology']
# Out:
#    Student initials       Year    Major  Homework 1  Homework 2  Homework 3  \
# 3                DD   Freshman  Biology         1.0         1.0         0.0
# 4                EE   Freshman  Biology         1.0         1.0         2.0
# 5                FF  Sophomore  Biology         3.0         4.0         3.0
# 8                II     Junior  Biology         4.0         2.0         5.0
# 9                JJ     Junior  Biology         3.0         3.0         4.0
# 11               LL     Senior  Biology         4.0         5.0         3.0
# 19               TT     Junior  Biology         2.0         1.0         3.0
# 20               UU   Freshman  Biology         3.0         0.0         0.0
# 24               YY  Sophomore  Biology         5.0         5.0         3.0
#
#     Homework 4  Exam 1  Exam 2  Project
# 3          3.0    13.0    14.0      5.0
# 4          0.0     8.0     8.0      6.0
# 5          2.0     6.0    13.0     20.0
# 8          1.0     6.0    18.0     24.0
# ...

# %% [markdown]
# ## Display the students who are Biology or CS majors

# %%
test_df[test_df['Major'].isin(['Biology','CS'])]
# Out:
#    Student initials       Year    Major  Homework 1  Homework 2  Homework 3  \
# 0                AA   Freshman       CS         2.0         2.0         1.0
# 1                BB   Freshman       CS         0.0         1.0         3.0
# 2                CC   Freshman       CS         3.0         2.0         3.0
# 3                DD   Freshman  Biology         1.0         1.0         0.0
# 4                EE   Freshman  Biology         1.0         1.0         2.0
# 5                FF  Sophomore  Biology         3.0         4.0         3.0
# 7                HH     Junior       CS         4.0         3.0         1.0
# 8                II     Junior  Biology         4.0         2.0         5.0
# 9                JJ     Junior  Biology         3.0         3.0         4.0
# 10               KK     Junior       CS         2.0         3.0         5.0
# 11               LL     Senior  Biology         4.0         5.0         3.0
# ...

# %% [markdown]
# ## Display the students who are Sophomore CS majors

# %%
t1 = test_df['Year'].map(lambda x: x.startswith('Sophomore'))

test_df[t1 & (test_df['Major'] == 'CS')]
# Out:
#    Student initials       Year Major  Homework 1  Homework 2  Homework 3  \
# 15               PP  Sophomore    CS         3.0         4.0         2.0
# 16               QQ  Sophomore    CS         3.0         4.0         3.0
#
#     Homework 4  Exam 1  Exam 2  Project
# 15         5.0    22.0    16.0     18.0
# 16         5.0    22.0    15.0     19.0

# %%
# Alternative
test_df[(test_df['Year'] == 'Sophomore') & (test_df['Major'] == 'CS')]
# Out:
#    Student initials       Year Major  Homework 1  Homework 2  Homework 3  \
# 15               PP  Sophomore    CS         3.0         4.0         2.0
# 16               QQ  Sophomore    CS         3.0         4.0         3.0
#
#     Homework 4  Exam 1  Exam 2  Project
# 15         5.0    22.0    16.0     18.0
# 16         5.0    22.0    15.0     19.0

# %% [markdown]
# ## Display only the homework grades for the Junior students

# %%
t1 = test_df['Year'].map(lambda x: x.startswith('Junior'))
test_df[t1][['Student initials', 'Year', 'Major', 'Homework 1', 'Homework 2', 'Homework 3', 'Homework 4']]
# Out:
#    Student initials    Year    Major  Homework 1  Homework 2  Homework 3  \
# 7                HH  Junior       CS         4.0         3.0         1.0
# 8                II  Junior  Biology         4.0         2.0         5.0
# 9                JJ  Junior  Biology         3.0         3.0         4.0
# 10               KK  Junior       CS         2.0         3.0         5.0
# 14               OO  Junior    Dance         5.0         4.0         4.0
# 19               TT  Junior  Biology         2.0         1.0         3.0
# 25               ZZ  Junior       CS         5.0         3.0         1.0
#
#     Homework 4
# 7          1.0
# 8          1.0
# 9          1.0
# 10         1.0
# 14         5.0
# 19         1.0
# 25         1.0

# %%
# Alternative
test_df.ix[:,'Homework 1':'Homework 4']
# Out:
#     Homework 1  Homework 2  Homework 3  Homework 4
# 0          2.0         2.0         1.0         2.0
# 1          0.0         1.0         3.0         2.0
# 2          3.0         2.0         3.0         3.0
# 3          1.0         1.0         0.0         3.0
# 4          1.0         1.0         2.0         0.0
# 5          3.0         4.0         3.0         2.0
# 6          4.0         4.0         4.0         5.0
# 7          4.0         3.0         1.0         1.0
# 8          4.0         2.0         5.0         1.0
# 9          3.0         3.0         4.0         1.0
# 10         2.0         3.0         5.0         1.0
# 11         4.0         5.0         3.0         4.0
# 12         4.0         2.0         3.0         5.0
# 13         1.0         4.0         1.0         2.0
# 14         5.0         4.0         4.0         5.0
# 15         3.0         4.0         2.0         5.0
# 16         3.0         4.0         3.0         5.0
# ...

# %%
# Alternative
test_df.ix[test_df['Year'] == 'Junior','Homework 1':'Homework 4']
# Out:
#     Homework 1  Homework 2  Homework 3  Homework 4
# 7          4.0         3.0         1.0         1.0
# 8          4.0         2.0         5.0         1.0
# 9          3.0         3.0         4.0         1.0
# 10         2.0         3.0         5.0         1.0
# 14         5.0         4.0         4.0         5.0
# 19         2.0         1.0         3.0         1.0
# 25         5.0         3.0         1.0         1.0

# %%
# Alternative
test_df.ix[test_df['Year'] == 'Junior',['Year','Homework 1','Homework 4']]
# Out:
#       Year  Homework 1  Homework 4
# 7   Junior         4.0         1.0
# 8   Junior         4.0         1.0
# 9   Junior         3.0         1.0
# 10  Junior         2.0         1.0
# 14  Junior         5.0         5.0
# 19  Junior         2.0         1.0
# 25  Junior         5.0         1.0

# %% [markdown]
# ## Compute the maximum, minimum, and mean project grade

# %%
test_df['Project'].describe()
# Out:
# count    26.000000
# mean     19.538462
# std       7.674533
# min       5.000000
# 25%      16.000000
# 50%      19.000000
# 75%      26.000000
# max      30.000000
# Name: Project, dtype: float64

# %% [markdown]
# ## Add a new grade column to the data frame
# The column Grade is the sum of the homework, exam, and project grades.  See pandas `apply` and define a new function to compute the grade or use a lambda function.

# %%
def my_test(a, b, c, d, e, f, g):
    return a + b + c + d + e + f + g
test_df['Sum'] = test_df.apply(lambda row: my_test(row['Homework 1'], row['Homework 2'], row['Homework 3'], row['Homework 4'],
                                                   row['Exam 1'], row['Exam 2'], row['Project']), axis=1)
test_df[:26]
# Out:
#    Student initials       Year    Major  Homework 1  Homework 2  Homework 3  \
# 0                AA   Freshman       CS         2.0         2.0         1.0
# 1                BB   Freshman       CS         0.0         1.0         3.0
# 2                CC   Freshman       CS         3.0         2.0         3.0
# 3                DD   Freshman  Biology         1.0         1.0         0.0
# 4                EE   Freshman  Biology         1.0         1.0         2.0
# 5                FF  Sophomore  Biology         3.0         4.0         3.0
# 6                GG  Sophomore    Dance         4.0         4.0         4.0
# 7                HH     Junior       CS         4.0         3.0         1.0
# 8                II     Junior  Biology         4.0         2.0         5.0
# 9                JJ     Junior  Biology         3.0         3.0         4.0
# 10               KK     Junior       CS         2.0         3.0         5.0
# ...

# %%
# Alternative
import numpy as np

## Intentially mis-specify and ignore the Project
def total_grade(row):
    return sum(row.ix['Homework 1':'Exam 2'])

test_df['Sum Alt'] = test_df.apply(lambda row: total_grade(row), axis=1)
print test_df['Sum'] == test_df['Sum Alt']
assert np.all(test_df['Sum'] == test_df['Sum Alt']), 'Sum and Sum Alt columns do not match'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# dtype: bool
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-60-0d5beca6ffff> in <module>()
#       8 test_df['Sum Alt'] = test_df.apply(lambda row: total_grade(row), axis=1)
#       9 print test_df['Sum'] == test_df['Sum Alt']
# ---> 10 assert np.all(test_df['Sum'] == test_df['Sum Alt']), 'Sum and Sum Alt columns do not match'
#
# AssertionError: Sum and Sum Alt columns do not match

# %% [markdown]
# ## Compute the mean grade for each type of major
# Use the new column created above

# %%
def my_mean(total):
    return total/7
test_df['mean'] = test_df.apply(lambda row: my_mean(row['Sum']), axis=1)
test_df[:26]
# Out:
#    Student initials       Year    Major  Homework 1  Homework 2  Homework 3  \
# 0                AA   Freshman       CS         2.0         2.0         1.0
# 1                BB   Freshman       CS         0.0         1.0         3.0
# 2                CC   Freshman       CS         3.0         2.0         3.0
# 3                DD   Freshman  Biology         1.0         1.0         0.0
# 4                EE   Freshman  Biology         1.0         1.0         2.0
# 5                FF  Sophomore  Biology         3.0         4.0         3.0
# 6                GG  Sophomore    Dance         4.0         4.0         4.0
# 7                HH     Junior       CS         4.0         3.0         1.0
# 8                II     Junior  Biology         4.0         2.0         5.0
# 9                JJ     Junior  Biology         3.0         3.0         4.0
# 10               KK     Junior       CS         2.0         3.0         5.0
# ...

# %%
# Alternative

groups = test_df.groupby('Major')
print list(groups)
print groups['Sum'].describe()
# Out:
# [('Biology',    Student initials       Year    Major  Homework 1  Homework 2  Homework 3  \
# 3                DD   Freshman  Biology         1.0         1.0         0.0
# 4                EE   Freshman  Biology         1.0         1.0         2.0
# 5                FF  Sophomore  Biology         3.0         4.0         3.0
# 8                II     Junior  Biology         4.0         2.0         5.0
# 9                JJ     Junior  Biology         3.0         3.0         4.0
# 11               LL     Senior  Biology         4.0         5.0         3.0
# 19               TT     Junior  Biology         2.0         1.0         3.0
# 20               UU   Freshman  Biology         3.0         0.0         0.0
# 24               YY  Sophomore  Biology         5.0         5.0         3.0
#
#     Homework 4  Exam 1  Exam 2  Project   Sum  Sum Alt       mean
# 3          3.0    13.0    14.0      5.0  37.0     32.0   5.285714
# ...

# %% [markdown]
# ## Plot a histogram of all grades
# See `%pylab inline`.  Include a title.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

test_df.hist();
#how to include a title?
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000007FE9C50>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009C686A0>]], dtype=object)

# %%
test_df['Sum'].hist();
plt.title('Grade distribution');
plt.xlabel('Grade');
plt.ylabel('Frequency');

# %% [markdown]
# ## Plot a histogram of Freshman students' grades.
# Include a title.

# %%
freshman_df = test_df['Year'].map(lambda x: x.startswith('Freshman'))
test_df[freshman_df].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009FCF278>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B83EE80>]], dtype=object)

# %% [markdown]
# ## Plot a scatterplot of exam 1 grade versus exam 2 grade
# Include a title and x- and y-axis labels.  Include a title.

# %%
#ex1 = test_df.as_matrix(by='Exam 1')
#ex2 = test_df.as_matrix(by='Exam 2')

stu = test_df['Exam 1'].count()
#test_df.scatter(stu,ex1, label = 'Line One')
#test_df.scatter(stu,ex2, label = 'Line Two')

y = test_df[['Exam 1']].as_matrix()
y = test_df[['Exam 1']].as_matrix()

# %%
# Lower level alternative
plt.plot(test_df['Exam 1'], test_df['Exam 2'], '.k');
plt.xlabel('Exam 1');
plt.ylabel('Exam 2');

# %%
# Alternative - required newer version of pandas
# Also seaborn http://seaborn.pydata.org/
test_df.plot.scatter(x = 'Exam 1', y = 'Exam 2');
# Out:
# C:\Program Files\Anaconda\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
print pd.__version__
# Out:
# 0.19.0
